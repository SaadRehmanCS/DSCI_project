# %% [markdown]
# # **Heart Failure Risk Analysis**

# %% [markdown]
# ## Introduction

# %% [markdown]
# **Background:** Heart failure occurs when the heart muscle doesn’t pump blood around the body correctly. This failure of the heart stems from a multitude of factors, such as high blood pressure or narrowed arteries. Heart failure is a condition of Cardiovascular disease (CVD), a disease that is the number 1 cause of death globally, taking ~17.9 million lives yearly. Heart failure affects everyone in some form, meaning it is vital that those who are at risk of heart failure know as soon as possible.
#
# **Question:** How accurate is our model in predicting whether a person dies from heart failure based on their age, blood pump fraction, creatinine level, and sodium level?
#
# **Dataset:** The dataset can be found here: https://www.kaggle.com/andrewmvd/heart-failure-clinical-data. (kaggle.com. (n.d.). Heart Failure Prediction. [online]).
#
# It includes 13 columns of data, 6 of which are binary. The binary data includes information regarding the patients wellbeing (e.g smoking). Meanwhile, the other quantitative data include information about the body of the patient (e.g. enzyme levels).
#
# We want to be able to use this data and apply a knn classification model to determine the likeliness of a death event to the patient based on their health level. Patients age range is 40-95 years.

# %% [markdown]
# ---

# %% [markdown]
# ## Methods & Results

# %%
library(tidyverse)
library(tidymodels)
library(repr)
library(GGally)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.2     ✔ purrr   0.3.4
# ✔ tibble  3.0.3     ✔ dplyr   1.0.2
# ✔ tidyr   1.1.2     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.5.0
#
# Warning message:
# “package ‘ggplot2’ was built under R version 4.0.1”
# Warning message:
# “package ‘tibble’ was built under R version 4.0.2”
# Warning message:
# “package ‘tidyr’ was built under R version 4.0.2”
# Warning message:
# “package ‘dplyr’ was built under R version 4.0.2”
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Warning message:
# “package ‘tidymodels’ was built under R version 4.0.2”
# ── Attaching packages ────────────────────────────────────── tidymodels 0.1.1 ──
#
# ✔ broom     0.7.0      ✔ recipes   0.1.13
# ✔ dials     0.0.9      ✔ rsample   0.0.7
# ✔ infer     0.5.4      ✔ tune      0.1.1
# ...

# %% [markdown]
# * Our first stage of analysis starts with importing the dataframe from Github, and converting death_event into a factor since it is our target variable. Factors convert the categories into levels, which we can easily manipulate while predicting.
# * Column names are renamed to improve user readability.

# %%
set.seed(69420)
#import the data from the web and convert DEATH_EVENT to a factor for future predictive modelling
heart_data_raw <- read_csv("https://raw.githubusercontent.com/SaadRehmanCS/DSCI_project/master/heart_failure_clinical_records_dataset.csv") %>%
                mutate(DEATH_EVENT = as_factor(DEATH_EVENT))

#rename column variables to improve user-readability         
colnames(heart_data_raw) <- c("patient_age","anaemia","cpk_enzyme_level", "diabetes",
                              "blood_pump_fraction", "high_blood_pressure", "platelets_level", "creatinine_level",
                              "sodium_level", "sex", "smoker", "time_of_failure", "death_event")
head(heart_data_raw)
# Out:
# Parsed with column specification:
# cols(
#   age = col_double(),
#   anaemia = col_double(),
#   creatinine_phosphokinase = col_double(),
#   diabetes = col_double(),
#   ejection_fraction = col_double(),
#   high_blood_pressure = col_double(),
#   platelets = col_double(),
#   serum_creatinine = col_double(),
#   serum_sodium = col_double(),
#   sex = col_double(),
#   smoking = col_double(),
#   time = col_double(),
#   DEATH_EVENT = col_double()
# )
#   patient_age anaemia cpk_enzyme_level diabetes blood_pump_fraction
# 1 75          0        582             0        20
# 2 55          0       7861             0        38
# 3 65          0        146             0        20
# 4 50          1        111             0        20
# 5 65          1        160             1        20
# 6 90          1         47             0        40
#   high_blood_pressure platelets_level creatinine_level sodium_level sex smoker
# ...

# %% [markdown]
# <div align="center">Table 1</div>

# %% [markdown]
# The variables used in this data set are:
# - **Age** [patient_age] - As people age the increased stiffness in the large arteries can lead to hypertension and possibly heart failure. (National Institute on Aging (2018))
#
# - **Anaemia** [anaemia] (Decrease of red blood cells or hemoglobin; 1 or 0)
#
# - **Creatinine Phosphokinase Level** [cpk_enzyme_level] (Level of the CPK enzyme in the blood)
#
# - **Diabetes** [diabetes] (If the patient diabetes or not; 1 or 0)
#
# - **Ejection Fraction** [blood_pump_fraction] (Percentage of blood leaving the heart at each contraction) - A ejection fraction measurement under 40 percent may be evidence of heart failure. (American Heart Association (2017))
#
# - **High Blood Pressure** [high_blood_pressure] (If the patient has high blood pressure or not; 1 or 0)
#
# - **Platelets** [platelets_level] (Amount of platelets present in the blood)
#
# - **Serum Creatinine** [creatinine_level] (Level of serum creatinine in the blood) - Elevated serum creatinine has been associated with increased mortality in hypertensive persons and the elderly (Wannamethee, S.G., Shaper, A.G. and Perry, I.J. (1997))
#
# - **Serum Sodium** [sodium_level] (Level of serum sodium in the blood) - patients with normal sodium levels had a higher chance of survival over patients with a serum sodium concentration of <135 mEq/L. (Gebresillassie, B.M. and Abegaz, T.M. (2018))
#
# - **Sex** [sex] (Male or female)
#
# - **Smoking** [smoker] (Whether the patient smokes or not; 1 or 0)
#
# - **Time of Death** [time_of_failure] (Follow up period, in days)
#
# - **Death** [death_event] (If the patient died during the follow-up period; 1 = death    0 = survived)

# %% [markdown]
# **Cleaning and wrangling data**
#
# We only want this analysis to focus on patients who have previous history with suffering from diabetes or high blood pressure. We remove any patients who do not fall under this category.

# %%
#pivot anaemia, diabetes, high_blood_pressure columns into a single column, and then remove patients with anaemia or no disease.
heart_data_condition <- heart_data_raw %>%
                pivot_longer(cols=c(anaemia, diabetes, high_blood_pressure), names_to="medical_condition", values_to="patient_has_it") %>%
                filter(patient_has_it == 1, medical_condition != "anaemia")

# %% [markdown]
# * We have removed columns that we feel will not provide us with any meaningful conclusions from our particular analysis.
# * Additionally, we have removed all cpk_enzyme_level values that cross the range of 1500. This is because it is a rare occurrence, and they lead to an unreasonably scaled axis when plotted on a visualisation. Removing them will give a more accurate and easy-to-read depiction of this column.

# %%
#remove columns that we are un-interested in, and only keep those we will actually use. Also remove abnormally high values of cpk_enzyme
heart_data <- heart_data_condition %>%
            select(-patient_has_it, -medical_condition, -time_of_failure, -sex, -smoker) %>%
            filter(cpk_enzyme_level < 1500)

# %% [markdown]
# * Data is split into training and testing sets in a 3:1 ratio respectively. The testing set is unused until we test the final accuracy of K. This will allow the model to remain unbiased, as per the golden rule of machine learning, when it predicts on the test set.
#
# - The training set will be used to train, cross validate, and tune our knn-model.

# %%
#split the data
heart_data_split <- initial_split(heart_data, prop = 0.75, strata = death_event)
#declare the training set
heart_data_train <- training(heart_data_split)
#declare the test set
heart_data_test <- testing(heart_data_split)

head(heart_data_train)
# Out:
#   patient_age cpk_enzyme_level blood_pump_fraction platelets_level
# 1 60          315              60                  454000
# 2 80          123              35                  388000
# 3 75           81              38                  368000
# 4 49           80              30                  427000
# 5 70          125              25                  237000
# 6 48          582              55                   87000
#   creatinine_level sodium_level death_event
# 1 1.1              131          1
# 2 9.4              133          1
# 3 4.0              131          1
# 4 1.0              138          0
# 5 1.0              140          1
# 6 1.9              121          1

# %% [markdown]
# <div align="center">Table 2</div>

# %% [markdown]
# * We would like to determine which variables have the greatest influence on death_event, and only use those variables in our model.
#
# - This is so that we have narrower and focused variables in our model. Facetted boxplots will help.

# %%
#declare plot axes labels
# source:
# https://stackoverflow.com/questions/3472980/how-to-change-facet-labels
#The variable names have been given more human-readable names for plotting purposes.
variable_names <- c(patient_age = "Patient age (Year)",
                    cpk_enzyme_level = "CPK enzyme level (mcg/L)",
                    blood_pump_fraction = "Pumped blood (percentage)",
                    platelets_level = "Platelets (kiloplatelets/mL)",
                    creatinine_level = "Creatinine level (mg/dL))",
                    sodium_level = "Sodium level (mEq/L)")

#pivot all columns from patient_age to sodium_level into one column named variable
pivoted_heart_data <- heart_data_train %>% 
                    pivot_longer(cols=c(patient_age:sodium_level), names_to="variable", values_to="value")

# %% [markdown]
# * This plot will create facetted boxplots for each predictor variable, used to discover relationships in each predictor for those that have survived, against those that have died.

# %%
#create facetted boxplots for each predictive variable
# source: 
# https://stackoverflow.com/questions/14604439/plot-multiple-boxplot-in-one-graph
heart_data_boxplot <- pivoted_heart_data %>% # all variables are merged in two columns one for the names and the other for values
                    ggplot(aes(x=variable, y=value)) +
                    geom_boxplot(aes(fill=death_event)) + 
                    facet_wrap( ~ variable, scales="free", labeller = as_labeller(variable_names))+    # boxplot theme based on death_event
                    labs(x = "Variable", y = "Value") +
                    scale_fill_discrete(name = "Death Event", labels = c("Survived", "Died")) +         # legend name and values name
                    theme(text = element_text(size=20), axis.text.x = element_blank())                  # text size

# %% [markdown]
# * We can see from the below plots that cpk_enzyme_level and platelets_level have roughly the same median, and a very similar IQR for boxplots of both categories. This means that both the people who survived, as well as died have similar levels of CPK enzyme and platelets, implying that including these variables in our analysis won't help in distinguishing between categories.
#
# - In comparison, survivors have a higher upper and lower quartile for pumped_blood_percentage. This hints at the possibility of a positive associative relationship between pumped_blood_percentage and death_event. Variables such as this will help with our model construction.
#
# * We conclude this visualization by choosing all the predictors below *besides* cpk_enzyme_level and platelets_level.

# %%
options(repr.plot.width = 18, repr.plot.height = 10)   # resize the shape
#plot the visualization
heart_data_boxplot
options(repr.plot.width = NULL, repr.plot.height = NULL) # set the default size for next figures.
# Out:
# plot without title

# %% [markdown]
# <div align="center">Figure 1</div>

# %% [markdown]
# * Summarized data for our chosen predictor variables; it shows us the minimum, maximum, mean values, and checks to see that we dont have any NA values in our dataframe.

# %%
#group the data by the variable name, and summarize min, max, mean, anyNA accordingly. Filter out redundant variables
summarized_heart_data <- pivoted_heart_data %>%
                        group_by(variable) %>%
                        summarize(min = min(value), max = max(value), mean = mean(value))  %>% 
                        mutate(anyNA = anyNA(variable)) %>%
                        filter(variable != "cpk_enzyme_level", variable != "platelets_level")

summarized_heart_data
# Out:
# `summarise()` ungrouping output (override with `.groups` argument)
#   variable            min   max   mean       anyNA
# 1 blood_pump_fraction  17.0  70.0  38.531250 FALSE
# 2 creatinine_level      0.6   9.4   1.380562 FALSE
# 3 patient_age          40.0  94.0  61.677087 FALSE
# 4 sodium_level        113.0 148.0 136.193750 FALSE

# %% [markdown]
# <div align="center">Table 3</div>

# %% [markdown]
# **Balancing**
#
# Creating a vector to store the number of people who survived, versus those who died. That is to find the proportionality between each value of our predictor so we decide whether our dataset needs to be balanced.

# %%
#select out the death_event column
death_event_column <- heart_data_train %>% select(death_event)

#create a vector to store the number of values for each of death_event == 0 and 1
number_of_people <- c(death_event_column %>% 
                      filter(death_event == 0) %>% 
                      nrow(), death_event_column %>% 
                      filter(death_event == 1) %>% 
                      nrow())
#create vector with column names
death_event <- c("survived", "died")

#create a data frame
df <- data.frame(death_event, number_of_people)

# %% [markdown]
# * We have created a bar plot visualisation of the number of people who died, against those who survived.
# * Almost twice as many people survived compared to those who had died. So the dataset needs to be balanced, to avoid majority-vote bias.

# %%
#create a barplot, with bars filled in by death_event. 
death_event_summary_plot <- ggplot(df, aes(x=death_event, y=number_of_people, fill = death_event)) +
                            geom_bar(stat="identity", width = 0.6) +
                            labs(x = NULL, y = "number of People")  +
                            scale_fill_manual(values = c("#00bfc4", "#f8766d"), name = "Death Event", labels = c("Died", "Survived")) +
                            theme(text = element_text(size = 20)) +
                            geom_text(aes(label=number_of_people), vjust=-0.5, size=5) +
                            guides(fill = guide_legend(reverse = TRUE))
       
death_event_summary_plot
# Out:
# plot without title

# %% [markdown]
# <div align="center">Figure 2</div>

# %% [markdown]
# * Removed the redundant columns. We decided not to use those variables based on the visualization results above.

# %%
#select only the relevent columns from the training set
heart_data_train <- select(heart_data_train, patient_age, blood_pump_fraction, creatinine_level:death_event)
#select only the relevent columns from the testing set
heart_data_test <- select(heart_data_test, patient_age, blood_pump_fraction, creatinine_level:death_event)

# %% [markdown]
# - We have created a ggpairs plot for additional exploratory analysis. This plots all relevant variables against each other to make a wide range of comparisons.
# - The histograms are used to compare death_event with each predictor. Survivors seem to be younger, with the distribution of survivors having smaller variation than the non-survivors in the patient_age column.
# - Survivors seemingly also have a higher sodium content than non-survivors by a marginal amount.
# - Survivors have a much higher creatinine level than non-survivors, and their plot also seems to have less variation, with a lower standard deviation.
# - The lower quartile of blood pump fraction for survivors is much higher than that of non-survivors, but the median range is very similar. This suggests that while most of the values for this variable are centered in the same range, there is less variability for survivors.

# %%
options(repr.plot.width = 12, repr.plot.height = 12)   # resize the shape

exploratory_plot <- heart_data_train %>%
            ggpairs(aes(color=death_event), lower=list(combo=wrap("facethist",  
            binwidth=2)), legend = 1) + theme(legend.position = "right", text = element_text(size=18))

exploratory_plot
# Out:
# plot without title

# %% [markdown]
# <div align="center">Figure 3</div>

# %% [markdown]
# - We have created a recipe using the training set, as well as used all variables as predictors with the classifier as the death event.
#
# - We have then scaled and centered all the predictors used. This is because each predictor uses a different scale of measurement, i.e. a change in blood pump fraction by 1 unit has less of an effect than change in age by 1 unit.

# %%
#create recipe and standardize data
heart_data_recipe <- recipe(death_event ~ ., data = heart_data_train) %>%
            step_scale(all_predictors()) %>%
            step_center(all_predictors())

# %% [markdown]
# - From the above summary plot, we can see that we have more observations for people that survived than those who died. For reasons discussed above, we have balanced the training dataset by upsampling the death event.
#
# - We have then prepped and baked the standardized data into a new dataframe, to pass in the recipe.

# %%
#data balancing of the training data with prep and bake to get a readable dataframe
heart_data_train_scaled <- heart_data_recipe %>%
                    step_upsample(death_event, over_ratio = 1, skip = FALSE) %>%
                    prep() %>%
                    bake(heart_data_train)
# Out:
# Warning message:
# “`step_upsample()` is deprecated as of recipes 0.1.13.
# Please use `themis::step_upsample()` instead.
# This warning is displayed once every 8 hours.
# Call `lifecycle::last_warnings()` to see where this warning was generated.”

# %% [markdown]
# - We have performed a cross-validation split on the scaled data. We used a 10-fold cross-validation rather than a 5 even though a higher v insinuates the need for more computational power and time. This is because we are dealing with life-determining medical data that needs to be as accurate as possible.
#
# - The validation shuffles the data to find multiple different accuracy values. We then take an average of these validations to get a single assessment of classifier accuracy. This means that the likelihood of the validation being poor was far lower.
#
# - The tibble gridvals allows us to implement specific values of k in the tuning.

# %%
#cross-validation split
heart_data_vfold <- vfold_cv(heart_data_train_scaled, v = 10, strata = death_event)
#tibble to store 10 different values for the neighbors(k). The values of k increase by 10, 
#to get a larger range of possible values. A larger range could help discover any unusual patterns in data as k gets larger.
gridvals <- tibble(neighbors = seq(from = 1, to = 101, by = 10))

# %% [markdown]
# - Then we create our classification model, with neighbours argument set to 'tune' for when we plot the various k-values later. Tuning allows us to look at the models accuracy with a range of k values, so that we can select the value that has a high accuracy while not dropping too low for its neighboring values.

# %%
#create knn classification model with tune() to collect different measurements of k
knn_spec <- nearest_neighbor(weight_func = "rectangular", neighbors = tune()) %>%
      set_engine("kknn") %>%
      set_mode("classification")

# %% [markdown]
# - With the workflow, by running tune_grid and collect_metrics we can acquire the mean value when our range of k-values are used. The workflow we created can then be used to compare various k-values.

# %%
#workflow with recipe and model, run tune_grid and collect_metrics to get the mean for each value of k
knn_fit <- workflow() %>%
         add_recipe(heart_data_recipe) %>%
         add_model(knn_spec) %>%
         tune_grid(resamples = heart_data_vfold, grid = gridvals) %>%
         collect_metrics()

# %% [markdown]
# - We filter the workflow to only include the accuracy in the .metrics column.
#
# - Next, we have made a plot of the workflow with neighbors on the x axis and the mean value on the y axis. We are looking for the highest mean value possible using the range of k-values.
#
# - For clarity, we adjust the element_text size, as well as the breaks for the scale so that it aligned with the k-values. We also add axis labels to ensure anyone viewing the graph would understand what is being plot.

# %%
#filter the df to only include accuracy in the .metrics column
knn_fit <- knn_fit %>%
            filter(.metric == "accuracy")
#plot the summary of means to make it visually easier to pick a neighbor value
knn_fit_plot <-  knn_fit %>%
            ggplot(aes(x = neighbors, y = mean)) +
            geom_point() +              #we used both the geom_point and geom_line functions to show the rises and falls of the k-value, 
            geom_line() +               #while also showcasing each point by plotting points.
            labs(x = "Number of neighbors", y = "Mean values") +
            scale_x_continuous(breaks = seq(1, 110, by = 10)) +  # adjusting the x-axis
            theme(text = element_text(size = 20))
knn_fit_plot
# Out:
# plot without title

# %% [markdown]
# <div align="center">Figure 4</div>

# %% [markdown]
# ### Chosen k-value: 2
# **Reasoning:** A k-value of 2 is in a sufficiently high range, but more importantly, has neighboring values that also predict high enough accuracy. Our choice of 2 is based on the fact that it has one of the highest mean values within the 1-10 range of neighbours. This means that it will provide the highest accuracy when used in tandem with our model.
#
# Although with larger values the accuracy drops significantly, the drop tends to level off at a rough 72.5%, which is the highest we can settle for.

# %% [markdown]
# - Using our chosen value of k, we have created another model using the optimum k-value.

# %%
#our chosen value of k
chosen_k = 2
#re-create the model, this time with a specific value of k
knn_spec_test <- nearest_neighbor(weight_func = "rectangular", neighbors = chosen_k) %>%
            set_engine("kknn") %>%
            set_mode("classification")

# %% [markdown]
# - Again, we add both the recipe and model, this time fitting the model to the training data.

# %%
#re-create the workflow, this time with the new model, and with the fit() function instead of tune_grid()
knn_fit_test <- workflow() %>%
            add_recipe(heart_data_recipe) %>%
            add_model(knn_spec_test) %>%
            fit(data = heart_data_train)

# %% [markdown]
# - We then predict the values of the testing data using the new model we created. We take the fit of the training data, and pip it through a predict function of the testing data. From there we bound the columns to the heart_data_test dataset. This creates our prediction to determine the accuracy of our model.

# %%
#predict the values of the testing set using the new trained model
heart_data_predict <- knn_fit_test %>%
            predict(heart_data_test) %>%
            bind_cols(heart_data_test)

# %% [markdown]
# - To assess the quality of our model, we run the metrics function on our prediction, comparing each predicted class against the real classification.
#
# - We specify the truth and estimate arguments, to determine the percentage of times the truth is equal to the estimate.
#
# - This gives us the accuracy of our model, which appears to be ~72%.

# %%
#run metrics to get the accuracy of the predictions
heart_data_accuracy <- heart_data_predict %>%
                metrics(truth = death_event, estimate = .pred_class)
heart_data_accuracy
# Out:
#   .metric  .estimator .estimate
# 1 accuracy binary     0.7169811
# 2 kap      binary     0.4373673

# %% [markdown]
# <div align="center">Table 4</div>

# %% [markdown]
# - To perform a further comparison of the accuracy of our model, we have created a confusion matrix to determine the heatmap of correct and incorrect predictions. Darker squares correspond to regions of higher concentration of values. Eg: The top left quadrant is quite dark, so it means there are several correctly predicted observations for patients who survived.

# %%
#run conf_mat to get the matrix of correct/wrong predictions
library(RColorBrewer)
options(repr.plot.width = 7, repr.plot.height = 7)   # resize the shape
heart_data_mat <- heart_data_predict %>%
            conf_mat(truth = death_event, estimate = .pred_class)
heart_data_mat
autoplot(heart_data_mat, type = "heatmap") + theme(text = element_text(size = 20))
# Out:
#           Truth
# Prediction  0  1
#          0 23  3
#          1 12 15
# plot without title

# %% [markdown]
# <div align="center">Figure 5</div>

# %% [markdown]
# ## Methods Overview
#
# The methods used in this report are repetitve and coherent.
#
# *Step 1* - Import data from GitHub repository to the Jupiter notebook and convert death_event into a factor since that is our target variable.
#
# *Step 2* - Filter out patients who have previous history with suffering from diabetes and anaemia.
#
# *Step 3* - Split the data into testing and training data with training being 75% and testing being 25%.
#
# *Step 4* - Create a facetted box plot to determine which variables have the greatest influence on death event.
#
# *Step 5* - From the facetted box plot, it can be concluded which variables have the least influence and thus they can be discarded. In our case it was cpk_enzyme_levels and platelets_levels.
#
# *Step 6* - Create a recipe with standardised data.
#
# *Step 7* - To avoid bias towards one category of patients, balance the training dataset by umsampling the death event.
#
# *Step 8* - Perform cross validation split on the trained data (our group performed a 10 fold cross validation for higher accuracy)
#
# *Step 9* - Create a classfication model and set the 'neighbors' argument to tune in order to select the value with the highest accuracy.
#
# *Step 10* - Create a workflow and find the accuracies of different k's by using tune_grid and collect_metrics.
#
# *Step 11* - Plot the visualisation to find the k with the highest mean value.
#
# *Step 12* - Re-create the model with the optimum k value achieved (in our case, 2).
#
# *Step 13* - Re-create the workflow with the new model and predict the values of the testing data using the new trained model.
#
# *Step 14* - Run the metrics function to get measure the accuracy of the predicition.
#
# *Step 15* - To further test the accuracy of the model, create a confusion matrix to find the correct and incorrect predictions.

# %% [markdown]
# ---

# %% [markdown]
# ## Discussion

# %% [markdown]
# **Summary of Findings:** We expect our model to correctly predict the likeliness of a patient dying from heart failure based on our selected variables ~70% of the time. We think that this percentage is insufficiently low considering the fact that we are looking at life/death predictors, where we would normally want accurate predictions atleast 95% of the time. We think the low percentage can be explained by examining our selected variables. One possible scenario is that they each have a weak relationship with respect to death_event, thus a lower accuracy. Alternatively, we may have selected too many predictors. When one predictor doesn't have a well defined relationship with the response variable, it can deter the performance of the entire model.

# %% [markdown]
# **Were the Findings what we expected?:** We expected to find that a higher age and creatinine level, as well as a lower blood pump fraction and sodium level, would lead to higher risk of death by heart failure. However, we *found* a very high likeliness of a type I error in our confusion matrix, which surprised us as it would be interpreted as our model predicting death in scenarios where the patient actually lived.
#
# **Impact of Findings:** If we can train our model to determine the risk of someone dying from heart failure, we can provide early warnings to people who are most at risk. This warning system could potentially save many lives, as the chance of survival drastically decreases when medical issues are left undetected. Moreover, this model can be used as a foundation of a much more advanced and comprehensive model which will take into account a greater number of varaibles and observations. Such a model can be extremly useful in the medical industry. Furthermore, if the model is also modified to take into account variables like family history, then this model can be used to predict wether the case of heart failure will arise in the patient in the furture or not.
#
# **Future Questions:** In the future we would like to further research whether or not the levels of creatinine, sodium, blood pump percentage, and age genuinely have a causal relationship with mortality, through experimentation. Further, we would like to test to see if decreasing the number of predictors has an effect on model accuracy or, if given more time and computational power, we can cross validate our model with a higher number of folds to be more certain of its accuracy,

# %% [markdown]
# ---

# %% [markdown]
# ## References

# %% [markdown]
# kaggle.com. (n.d.). Heart Failure Prediction. [online] Available at: https://www.kaggle.com/andrewmvd/heart-failure-clinical-data.

# %% [markdown]
# Abebe, T.B., Gebreyohannes, E.A., Tefera, Y.G., Bhagavathula, A.S., Erku, D.A., Belachew, S.A., Gebresillassie, B.M. and Abegaz, T.M. (2018). The prognosis of heart failure patients: Does sodium level play a significant role? PLoS ONE, [online] 13(11). Available at: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6224129/

# %% [markdown]
# American Heart Association (2017). Ejection Fraction Heart Failure Measurement. [online] www.heart.org. Available at: https://www.heart.org/en/health-topics/heart-failure/diagnosing-heart-failure/ejection-fraction-heart-failure-measurement.

# %% [markdown]
# Wannamethee, S.G., Shaper, A.G. and Perry, I.J. (1997). Serum Creatinine Concentration and Risk of Cardiovascular Disease. Stroke, 28(3), pp.557–563.

# %% [markdown]
# National Institute on Aging (2018). Heart Health and Aging. [online] National Institute on Aging. Available at: https://www.nia.nih.gov/health/heart-health-and-aging.

# %% [markdown]
# Bhf.org.uk. (2019). Heart failure. [online] Available at: https://www.bhf.org.uk/informationsupport/conditions/heart-failure.
